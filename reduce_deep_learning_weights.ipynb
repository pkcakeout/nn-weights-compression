# %%
from magic_values import *

# %%
import struct
import numpy as np

def classify_float_chunks(raw_data):
    offsets = []
    if len(raw_data) < FLOAT_WIDTH:
        return offsets
    
    byte_shift_unpackers = [
        iter(struct.iter_unpack("f", raw_data[i:(len(raw_data) - i) // FLOAT_WIDTH * FLOAT_WIDTH + i]))
        for i in range(FLOAT_WIDTH)
    ]
    
    current_chunk_offset = None
    
    byte_shift_buffers = [[] for _ in byte_shift_unpackers]
    
    float_offset = 0
    while True:
        # Fill byte shift buffers
        for i, (unpacker, buffer) in enumerate(zip(byte_shift_unpackers, byte_shift_buffers)):
            if unpacker:
                try:
                    while len(buffer) < FLOAT_DETECT_CHAIN_LENGTH:
                        buffer.append(next(unpacker)[0])
                except StopIteration:
                    byte_shift_unpackers[i] = None
        
        if (FLOAT_WIDTH * float_offset) % 1000000 == 0:
            print(f"{FLOAT_WIDTH * float_offset / 1000} kBytes")
        
        if current_chunk_offset is None:
            for i, buffer in enumerate(byte_shift_buffers):
                if buffer:
                    if (np.abs(np.array(buffer)) < FLOAT_DETECT_ABS_HIGH_LIMIT).mean() > FLOAT_DETECT_THRESHOLD:
                        current_chunk_offset = FLOAT_WIDTH * float_offset + i
                        break
            if current_chunk_offset:
                print(f"Found chunk starting at: {current_chunk_offset}")
        if current_chunk_offset is not None:
            buffer = byte_shift_buffers[current_chunk_offset % FLOAT_WIDTH]
            if (np.abs(np.array(buffer)) < FLOAT_DETECT_ABS_HIGH_LIMIT).mean() < FLOAT_UNDETECT_THRESHOLD:
                i = current_chunk_offset % FLOAT_WIDTH
                offsets.append((current_chunk_offset, FLOAT_WIDTH * float_offset + i))
                print(f"Chunk ended: {FLOAT_WIDTH * float_offset + i}")
                current_chunk_offset = None

        # Consume one float from each buffer
        for buffer in byte_shift_buffers:
            if buffer:
                buffer.pop(0)
        if not any(bool(x) for x in byte_shift_buffers):
            if current_chunk_offset is not None:
                i = current_chunk_offset % FLOAT_WIDTH
                offsets.append((current_chunk_offset, FLOAT_WIDTH * float_offset + i))
                print(f"Chunk ended: {FLOAT_WIDTH * float_offset + i}")
                current_chunk_offset = None
            break
        
        float_offset += 1
                
    return offsets

with open("resnet.npy", "rb") as f:
    data = f.read()
    
chunks = classify_float_chunks(data)
print(chunks)
# Out:
# 0.0 kBytes
# Found chunk starting at: 1
# Chunk ended: 137
# Found chunk starting at: 241
# /home/paul/.local/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in less
# /home/paul/.local/lib/python3.6/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in less
# 1000.0 kBytes
# Chunk ended: 1329065
# Found chunk starting at: 1329070
# 2000.0 kBytes
# 3000.0 kBytes
# Chunk ended: 3537130
# Found chunk starting at: 3537132
# Chunk ended: 3734256
# Found chunk starting at: 3734261
# Chunk ended: 3964969
# Found chunk starting at: 3964972
# 4000.0 kBytes
# Chunk ended: 4172328
# Found chunk starting at: 4172334
# Chunk ended: 4753358
# Found chunk starting at: 4753360
# Chunk ended: 4834764
# Found chunk starting at: 4834769
# 5000.0 kBytes
# Chunk ended: 5066093
# Found chunk starting at: 5066096
# Chunk ended: 5091928
# Found chunk starting at: 5091933
# Chunk ended: 5276373
# Found chunk starting at: 5276378
# Chunk ended: 5394694
# Found chunk starting at: 5394697
# Chunk ended: 5486717
# Found chunk starting at: 5486722
# 6000.0 kBytes
# 7000.0 kBytes
# Chunk ended: 7993802
# Found chunk starting at: 7993807
# 8000.0 kBytes
# Chunk ended: 8309839
# Found chunk starting at: 8309841
# 9000.0 kBytes
# 10000.0 kBytes
# 11000.0 kBytes
# 12000.0 kBytes
# Chunk ended: 12303321
# Found chunk starting at: 12303324
# Chunk ended: 12356420
# Found chunk starting at: 12356427
# 13000.0 kBytes
# Chunk ended: 13077687
# Found chunk starting at: 13077688
# 14000.0 kBytes
# 15000.0 kBytes
# Chunk ended: 15275096
# Found chunk starting at: 15275101
# Chunk ended: 15464133
# Found chunk starting at: 15464138
# Chunk ended: 15650074
# Found chunk starting at: 15650077
# 16000.0 kBytes
# 17000.0 kBytes
# 18000.0 kBytes
# 19000.0 kBytes
# 20000.0 kBytes
# 21000.0 kBytes
# 22000.0 kBytes
# 23000.0 kBytes
# 24000.0 kBytes
# 25000.0 kBytes
# Chunk ended: 25164673
# Found chunk starting at: 25164676
# 26000.0 kBytes
# 27000.0 kBytes
# 28000.0 kBytes
# 29000.0 kBytes
# 30000.0 kBytes
# 31000.0 kBytes
# 32000.0 kBytes
# 33000.0 kBytes
# 34000.0 kBytes
# 35000.0 kBytes
# 36000.0 kBytes
# 37000.0 kBytes
# 38000.0 kBytes
# 39000.0 kBytes
# Chunk ended: 39878020
# Found chunk starting at: 39878026
# 40000.0 kBytes
# Chunk ended: 40266334
# Found chunk starting at: 40266337
# Chunk ended: 40400745
# Found chunk starting at: 40400750
# 41000.0 kBytes
# Chunk ended: 41620950
# Found chunk starting at: 41620952
# Chunk ended: 41643364
# Found chunk starting at: 41643369
# Chunk ended: 41675157
# Found chunk starting at: 41675160
# Chunk ended: 41725660
# Found chunk starting at: 41725665
# 42000.0 kBytes
# Chunk ended: 42002029
# Found chunk starting at: 42002034
# Chunk ended: 42141446
# Found chunk starting at: 42141449
# Chunk ended: 42295417
# Found chunk starting at: 42295422
# Chunk ended: 42633718
# Found chunk starting at: 42633721
# Chunk ended: 42748317
# Found chunk starting at: 42748323
# 43000.0 kBytes
# 44000.0 kBytes
# 45000.0 kBytes
# 46000.0 kBytes
# 47000.0 kBytes
# Chunk ended: 47146911
# Found chunk starting at: 47146913
# Chunk ended: 47334041
# Found chunk starting at: 47334046
# 48000.0 kBytes
# 49000.0 kBytes
# 50000.0 kBytes
# 51000.0 kBytes
# 52000.0 kBytes
# Chunk ended: 52903882
# Found chunk starting at: 52903884
# Chunk ended: 52917852
# Found chunk starting at: 52917858
# 53000.0 kBytes
# Chunk ended: 53267394
# Found chunk starting at: 53267396
# Chunk ended: 53280004
# Found chunk starting at: 53280011
# 54000.0 kBytes
# 55000.0 kBytes
# 56000.0 kBytes
# 57000.0 kBytes
# Chunk ended: 57819195
# Found chunk starting at: 57819196
# Chunk ended: 57834632
# Found chunk starting at: 57834637
# 58000.0 kBytes
# Chunk ended: 58280649
# Found chunk starting at: 58280654
# Chunk ended: 58885450
# Found chunk starting at: 58885452
# 59000.0 kBytes
# Chunk ended: 59944292
# Found chunk starting at: 59944297
# 60000.0 kBytes
# Chunk ended: 60983329
# Found chunk starting at: 60983334
# 61000.0 kBytes
# 62000.0 kBytes
# Chunk ended: 62372254
# Found chunk starting at: 62372256
# 63000.0 kBytes
# Chunk ended: 63428548
# Found chunk starting at: 63428553
# 64000.0 kBytes
# 65000.0 kBytes
# 66000.0 kBytes
# 67000.0 kBytes
# 68000.0 kBytes
# 69000.0 kBytes
# 70000.0 kBytes
# 71000.0 kBytes
# 72000.0 kBytes
# Chunk ended: 72263145
# Found chunk starting at: 72263148
# Chunk ended: 72289228
# Found chunk starting at: 72289234
# 73000.0 kBytes
# Chunk ended: 73643150
# Found chunk starting at: 73643152
# Chunk ended: 73657776
# Found chunk starting at: 73657781
# Chunk ended: 73755089
# Found chunk starting at: 73755095
# 74000.0 kBytes
# Chunk ended: 74471383
# Found chunk starting at: 74471384
# 75000.0 kBytes
# Chunk ended: 75669856
# Found chunk starting at: 75669861
# 76000.0 kBytes
# Chunk ended: 76821085
# Found chunk starting at: 76821090
# Chunk ended: 76959622
# Found chunk starting at: 76959627
# 77000.0 kBytes
# Chunk ended: 77361755
# Found chunk starting at: 77361756
# 78000.0 kBytes
# Chunk ended: 78470228
# Found chunk starting at: 78470233
# 79000.0 kBytes
# 80000.0 kBytes
# 81000.0 kBytes
# 82000.0 kBytes
# 83000.0 kBytes
# 84000.0 kBytes
# 85000.0 kBytes
# Chunk ended: 85744153
# Found chunk starting at: 85744158
# 86000.0 kBytes
# Chunk ended: 86825994
# Found chunk starting at: 86825997
# Chunk ended: 86870909
# Found chunk starting at: 86870914
# Chunk ended: 86995742
# Found chunk starting at: 86995744
# 87000.0 kBytes
# Chunk ended: 87048812
# Found chunk starting at: 87048817
# Chunk ended: 87142729
# Found chunk starting at: 87142732
# Chunk ended: 87280080
# Found chunk starting at: 87280086
# Chunk ended: 87958130
# Found chunk starting at: 87958132
# Chunk ended: 87968540
# Found chunk starting at: 87968546
# 88000.0 kBytes
# 89000.0 kBytes
# 90000.0 kBytes
# Chunk ended: 90639162
# Found chunk starting at: 90639164
# Chunk ended: 90873708
# Found chunk starting at: 90873713
# Chunk ended: 90895057
# Found chunk starting at: 90895060
# 91000.0 kBytes
# Chunk ended: 91155632
# Found chunk starting at: 91155639
# 92000.0 kBytes
# 93000.0 kBytes
# 94000.0 kBytes
# 95000.0 kBytes
# 96000.0 kBytes
# Chunk ended: 96513767
# Found chunk starting at: 96513768
# Chunk ended: 96547868
# Found chunk starting at: 96547873
# 97000.0 kBytes
# Chunk ended: 97192661
# Found chunk starting at: 97192666
# 98000.0 kBytes
# Chunk ended: 98182686
# Found chunk starting at: 98182688
# Chunk ended: 98450084
# Found chunk starting at: 98450089
# Chunk ended: 98755201
# Found chunk starting at: 98755206
# 99000.0 kBytes
# 100000.0 kBytes
# Chunk ended: 100788022
# Found chunk starting at: 100788024
# 101000.0 kBytes
# Chunk ended: 101421304
# Found chunk starting at: 101421309
# 102000.0 kBytes
# Chunk ended: 102453353
# Found chunk starting at: 102453358
# Chunk ended: 102453358
# [(1, 137), (241, 1329065), (1329070, 3537130), (3537132, 3734256), (3734261, 3964969), (3964972, 4172328), (4172334, 4753358), (4753360, 4834764), (4834769, 5066093), (5066096, 5091928), (5091933, 5276373), (5276378, 5394694), (5394697, 5486717), (5486722, 7993802), (7993807, 8309839), (8309841, 12303321), (12303324, 12356420), (12356427, 13077687), (13077688, 15275096), (15275101, 15464133), (15464138, 15650074), (15650077, 25164673), (25164676, 39878020), (39878026, 40266334), (40266337, 40400745), (40400750, 41620950), (41620952, 41643364), (41643369, 41675157), (41675160, 41725660), (41725665, 42002029), (42002034, 42141446), (42141449, 42295417), (42295422, 42633718), (42633721, 42748317), (42748323, 47146911), (47146913, 47334041), (47334046, 52903882), (52903884, 52917852), (52917858, 53267394), (53267396, 53280004), (53280011, 57819195), (57819196, 57834632), (57834637, 58280649), (58280654, 58885450), (58885452, 59944292), (59944297, 60983329), (60983334, 62372254), (62372256, 63428548), (63428553, 72263145), (72263148, 72289228), (72289234, 73643150), (73643152, 73657776), (73657781, 73755089), (73755095, 74471383), (74471384, 75669856), (75669861, 76821085), (76821090, 76959622), (76959627, 77361755), (77361756, 78470228), (78470233, 85744153), (85744158, 86825994), (86825997, 86870909), (86870914, 86995742), (86995744, 87048812), (87048817, 87142729), (87142732, 87280080), (87280086, 87958130), (87958132, 87968540), (87968546, 90639162), (90639164, 90873708), (90873713, 90895057), (90895060, 91155632), (91155639, 96513767), (96513768, 96547868), (96547873, 97192661), (97192666, 98182686), (98182688, 98450084), (98450089, 98755201), (98755206, 100788022), (100788024, 101421304), (101421309, 102453353), (102453358, 102453358)]

# %%
def process_chunk(data, chunk):
    before = data[:chunk[0]]
    after = data[chunk[1]:]
    data = data[chunk[0]:chunk[1]]
    print(f"Len: {chunk}   {len(before)} + {len(data)} + {len(after)} = {len(before) + len(data) + len(after)}")
    
    data_iterator = iter(struct.iter_unpack("I", data))
    
    exponents = []
    mantissas = []
    for v in data_iterator:
        v = v[0]
        exponents.append(((v & 0x7F800000) >> 23) & 0x000000FF)
        
        m = (v & 0x007FFFFF) | ((v & 0x80000000) >> 8)
        mantissas.append((m >> 16) & 0xFF)
        mantissas.append((m >> 8) & 0xFF)
        mantissas.append((m >> 0) & 0xFF)

    exponents = struct.pack(f"{len(exponents)}B", *exponents)
    mantissas = struct.pack(f"{len(mantissas)}B", *mantissas)
    print(f" -> {len(exponents)} {len(mantissas)}")
    
    float_count = struct.pack("I", len(exponents))
    
    return before + MAGIC_MARKER + float_count + exponents + mantissas + after

new_data = bytes(data)
for chunk in reversed(chunks):
    new_data = process_chunk(new_data, chunk)

with open("test_file", "wb") as f:
    f.write(new_data)
# Out:
# Len: (102453358, 102453358)   102453358 + 0 + 4 = 102453362
#  -> 0 0
# Len: (101421309, 102453353)   101421309 + 1032044 + 22 = 102453375
#  -> 258011 774033
# Len: (100788024, 101421304)   100788024 + 633280 + 1032084 = 102453388
#  -> 158320 474960
# Len: (98755206, 100788022)   98755206 + 2032816 + 1665379 = 102453401
#  -> 508204 1524612
# Len: (98450089, 98755201)   98450089 + 305112 + 3698213 = 102453414
#  -> 76278 228834
# Len: (98182688, 98450084)   98182688 + 267396 + 4003343 = 102453427
#  -> 66849 200547
# Len: (97192666, 98182686)   97192666 + 990020 + 4270754 = 102453440
#  -> 247505 742515
# Len: (96547873, 97192661)   96547873 + 644788 + 5260792 = 102453453
#  -> 161197 483591
# Len: (96513768, 96547868)   96513768 + 34100 + 5905598 = 102453466
#  -> 8525 25575
# Len: (91155639, 96513767)   91155639 + 5358128 + 5939712 = 102453479
#  -> 1339532 4018596
# Len: (90895060, 91155632)   90895060 + 260572 + 11297860 = 102453492
#  -> 65143 195429
# Len: (90873713, 90895057)   90873713 + 21344 + 11558448 = 102453505
#  -> 5336 16008
# Len: (90639164, 90873708)   90639164 + 234544 + 11579810 = 102453518
#  -> 58636 175908
# Len: (87968546, 90639162)   87968546 + 2670616 + 11814369 = 102453531
#  -> 667654 2002962
# Len: (87958132, 87968540)   87958132 + 10408 + 14485004 = 102453544
#  -> 2602 7806
# Len: (87280086, 87958130)   87280086 + 678044 + 14495427 = 102453557
#  -> 169511 508533
# Len: (87142732, 87280080)   87142732 + 137348 + 15173490 = 102453570
#  -> 34337 103011
# Len: (87048817, 87142729)   87048817 + 93912 + 15310854 = 102453583
#  -> 23478 70434
# Len: (86995744, 87048812)   86995744 + 53068 + 15404784 = 102453596
#  -> 13267 39801
# Len: (86870914, 86995742)   86870914 + 124828 + 15457867 = 102453609
#  -> 31207 93621
# Len: (86825997, 86870909)   86825997 + 44912 + 15582713 = 102453622
#  -> 11228 33684
# Len: (85744158, 86825994)   85744158 + 1081836 + 15627641 = 102453635
#  -> 270459 811377
# Len: (78470233, 85744153)   78470233 + 7273920 + 16709495 = 102453648
#  -> 1818480 5455440
# Len: (77361756, 78470228)   77361756 + 1108472 + 23983433 = 102453661
#  -> 277118 831354
# Len: (76959627, 77361755)   76959627 + 402128 + 25091919 = 102453674
#  -> 100532 301596
# Len: (76821090, 76959622)   76821090 + 138532 + 25494065 = 102453687
#  -> 34633 103899
# Len: (75669861, 76821085)   75669861 + 1151224 + 25632615 = 102453700
#  -> 287806 863418
# Len: (74471384, 75669856)   74471384 + 1198472 + 26783857 = 102453713
#  -> 299618 898854
# Len: (73755095, 74471383)   73755095 + 716288 + 27982343 = 102453726
#  -> 179072 537216
# Len: (73657781, 73755089)   73657781 + 97308 + 28698650 = 102453739
#  -> 24327 72981
# Len: (73643152, 73657776)   73643152 + 14624 + 28795976 = 102453752
#  -> 3656 10968
# Len: (72289234, 73643150)   72289234 + 1353916 + 28810615 = 102453765
#  -> 338479 1015437
# Len: (72263148, 72289228)   72263148 + 26080 + 30164550 = 102453778
#  -> 6520 19560
# Len: (63428553, 72263145)   63428553 + 8834592 + 30190646 = 102453791
#  -> 2208648 6625944
# Len: (62372256, 63428548)   62372256 + 1056292 + 39025256 = 102453804
#  -> 264073 792219
# Len: (60983334, 62372254)   60983334 + 1388920 + 40081563 = 102453817
#  -> 347230 1041690
# Len: (59944297, 60983329)   59944297 + 1039032 + 41470501 = 102453830
#  -> 259758 779274
# Len: (58885452, 59944292)   58885452 + 1058840 + 42509551 = 102453843
#  -> 264710 794130
# Len: (58280654, 58885450)   58280654 + 604796 + 43568406 = 102453856
#  -> 151199 453597
# Len: (57834637, 58280649)   57834637 + 446012 + 44173220 = 102453869
#  -> 111503 334509
# Len: (57819196, 57834632)   57819196 + 15436 + 44619250 = 102453882
#  -> 3859 11577
# Len: (53280011, 57819195)   53280011 + 4539184 + 44634700 = 102453895
#  -> 1134796 3404388
# Len: (53267396, 53280004)   53267396 + 12608 + 49173904 = 102453908
#  -> 3152 9456
# Len: (52917858, 53267394)   52917858 + 349536 + 49186527 = 102453921
#  -> 87384 262152
# Len: (52903884, 52917852)   52903884 + 13968 + 49536082 = 102453934
#  -> 3492 10476
# Len: (47334046, 52903882)   47334046 + 5569836 + 49550065 = 102453947
#  -> 1392459 4177377
# Len: (47146913, 47334041)   47146913 + 187128 + 55119919 = 102453960
#  -> 46782 140346
# Len: (42748323, 47146911)   42748323 + 4398588 + 55307062 = 102453973
#  -> 1099647 3298941
# Len: (42633721, 42748317)   42633721 + 114596 + 59705669 = 102453986
#  -> 28649 85947
# Len: (42295422, 42633718)   42295422 + 338296 + 59820281 = 102453999
#  -> 84574 253722
# Len: (42141449, 42295417)   42141449 + 153968 + 60158595 = 102454012
#  -> 38492 115476
# Len: (42002034, 42141446)   42002034 + 139412 + 60312579 = 102454025
#  -> 34853 104559
# Len: (41725665, 42002029)   41725665 + 276364 + 60452009 = 102454038
#  -> 69091 207273
# Len: (41675160, 41725660)   41675160 + 50500 + 60728391 = 102454051
#  -> 12625 37875
# Len: (41643369, 41675157)   41643369 + 31788 + 60778907 = 102454064
#  -> 7947 23841
# Len: (41620952, 41643364)   41620952 + 22412 + 60810713 = 102454077
#  -> 5603 16809
# Len: (40400750, 41620950)   40400750 + 1220200 + 60833140 = 102454090
#  -> 305050 915150
# Len: (40266337, 40400745)   40266337 + 134408 + 62053358 = 102454103
#  -> 33602 100806
# Len: (39878026, 40266334)   39878026 + 388308 + 62187782 = 102454116
#  -> 97077 291231
# Len: (25164676, 39878020)   25164676 + 14713344 + 62576109 = 102454129
#  -> 3678336 11035008
# Len: (15650077, 25164673)   15650077 + 9514596 + 77289469 = 102454142
#  -> 2378649 7135947
# Len: (15464138, 15650074)   15464138 + 185936 + 86804081 = 102454155
#  -> 46484 139452
# Len: (15275101, 15464133)   15275101 + 189032 + 86990035 = 102454168
#  -> 47258 141774
# Len: (13077688, 15275096)   13077688 + 2197408 + 87179085 = 102454181
#  -> 549352 1648056
# Len: (12356427, 13077687)   12356427 + 721260 + 89376507 = 102454194
#  -> 180315 540945
# Len: (12303324, 12356420)   12303324 + 53096 + 90097787 = 102454207
#  -> 13274 39822
# Len: (8309841, 12303321)   8309841 + 3993480 + 90150899 = 102454220
#  -> 998370 2995110
# Len: (7993807, 8309839)   7993807 + 316032 + 94144394 = 102454233
#  -> 79008 237024
# Len: (5486722, 7993802)   5486722 + 2507080 + 94460444 = 102454246
#  -> 626770 1880310
# Len: (5394697, 5486717)   5394697 + 92020 + 96967542 = 102454259
#  -> 23005 69015
# Len: (5276378, 5394694)   5276378 + 118316 + 97059578 = 102454272
#  -> 29579 88737
# Len: (5091933, 5276373)   5091933 + 184440 + 97177912 = 102454285
#  -> 46110 138330
# Len: (5066096, 5091928)   5066096 + 25832 + 97362370 = 102454298
#  -> 6458 19374
# Len: (4834769, 5066093)   4834769 + 231324 + 97388218 = 102454311
#  -> 57831 173493
# Len: (4753360, 4834764)   4753360 + 81404 + 97619560 = 102454324
#  -> 20351 61053
# Len: (4172334, 4753358)   4172334 + 581024 + 97700979 = 102454337
#  -> 145256 435768
# Len: (3964972, 4172328)   3964972 + 207356 + 98282022 = 102454350
#  -> 51839 155517
# Len: (3734261, 3964969)   3734261 + 230708 + 98489394 = 102454363
#  -> 57677 173031
# Len: (3537132, 3734256)   3537132 + 197124 + 98720120 = 102454376
#  -> 49281 147843
# Len: (1329070, 3537130)   1329070 + 2208060 + 98917259 = 102454389
#  -> 552015 1656045
# Len: (241, 1329065)   241 + 1328824 + 101125337 = 102454402
#  -> 332206 996618
# Len: (1, 137)   1 + 136 + 102454278 = 102454415
#  -> 34 102

# %%
1328824 / 4

# %%
1 - 88536992 / 94395924
# Out:
# 0.06206763758147016
